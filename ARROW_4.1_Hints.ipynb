# %% [markdown]
# # ARROW Python Activities, 4.1 Hints, Tips, and Code Snippets

# %% [markdown]
# This notebook contains hints, tips and code snippets that you might find useful in completing Activity 4.1
#
# GENERAL HINT: Read in the main spectral data using Pandas.
#
# GENERAL HINT: You can display the spectrum using either Matplotlib or Bokeh. Matplotlib is superficially easier but Bokeh will be more useful later on.
#
# GENERAL HINT: Review the 'Pandas' and 'Bokeh' notebooks which you first used in Week 1

# %% [markdown]
# ### Step 1 - Get the data
#
# Generally, the ARROW spectral data contain 12 lines of header comments. The next line contains the names of the data columns ('frequency' and 'intensity'). The actual 2 data columns then follow.
#
# Use Pandas to read this data in - skipping the header lines.
#
# HINT: Don't forget to import the packages/modules you'll need

# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.models.tools import HoverTool

# %%
number_header_lines=12
#file_name = input('Enter spectrum file name ')
file_name = '080-orig.csv' # For debugging purposes to save typing

# Read in the data
spectrum_df = pd.read_csv(file_name, header=number_header_lines)

# %% [markdown]
# This will read the data into a pandas DataFrame with column names taken from the spectrum file. Remeber that you can use a specific column using these names. For example, if you had a dataframe formed form the ARROW data called 'df', then "df['intensity']" would indicate the column with 'intensity' as its header.

# %% [markdown]
# ### Step 3 - Display it (Simple Form)

# %%
output_notebook()
p = figure(title = "Put your Title here", 
          x_axis_label='Frequency (Hz)', 
          y_axis_label='Intensity')
p.line(spectrum_df['frequency'], fill in the DataFrame y values here)
#p.line(spectrum_df['frequency'], spectrum_df['intensity'])
#p.add_tools(HoverTool(mode='vline'))
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9ae873fe-0891-4a3b-a68e-8e9946e9beae" data-root-id="1002"></div>

# %% [markdown]
# ### Step 3a - Display it (but with added inspection tools)
#
# This is fine and works well with Jupyter notebooks but by adding some Bokeh tools - in particular the 'HoverTool' - you wil be able to get much more out of your inspection.
#
# The 'Bokeh' notebook explains how to do this (just use the add_tools() function to the code above) in the "Adding tools - particularly the HoverTool' section.
#
# HINT: You'll need the 'add_tools()' function.
#
# You can save a PNG image of the plot using the Bokeh sidebar.
